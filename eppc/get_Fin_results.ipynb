# %%
import csv
import os
import json
import numpy as np
models = [
    # "deepseek-ai/DeepSeek-V3",
    # "deepseek-ai/DeepSeek-R1",
    # "meta-llama/Llama-3.3-70B-Instruct",
    # "meta-llama/Llama-3.1-70B-Instruct",
    #"deepseek-ai/DeepSeek-R1-Distill-Llama-70B",
    "google/gemma-2-27b-it",
    "deepseek-ai/DeepSeek-R1-Distill-Qwen-32B",
    "Qwen/QwQ-32B-AWQ",
    "YanAdjeNole/sdoh-llama-3.3-70b"
    # "Qwen/Qwen2.5-14B-Instruct-1M",
    # "meta-llama/Llama-3.1-8B-Instruct",
    # "mistralai/Mistral-7B-Instruct-v0.3",
    # "meta-llama/Llama-3.2-3B-Instruct",
    # "meta-llama/Llama-3.2-1B-Instruct",
    # "Qwen/Qwen2.5-1.5B-Instruct"
]

# models = [
#     #"google/gemma-2-27b-it",
#     "deepseek-ai/DeepSeek-R1-Distill-Qwen-32B",
#     #"Qwen/QwQ-32B-AWQ",
#     #"YanAdjeNole/sdoh-llama-3.3-70b"
# ]
terms = ["code", "sub-code", "span"]
metrics = ["P", "R", "f1"]
def get_list(model_name, temps):
    assert len(temps) == 5
    ret = []
    for t in terms:
        line = [model_name, t]
        p_list = []
        r_list = []
        f_list = []
        for i in range(5):
            temp = temps[i]
            for m in metrics:
                #line.append(str(round(100* temp[t][m], 2)))
                line.append(round(temp[t][m], 4))
            p_list.append(temp[t]["P"])
            r_list.append(temp[t]["R"])
            f_list.append(temp[t]["f1"])
        # pfinal = f"{100* np.mean(p_list)} +- {100* np.std(p_list)}"
        # rfinal = f"{100* np.mean(r_list)} +- {100* np.std(r_list)}"
        # ffinal = f"{100* np.mean(f_list)} +- {100* np.std(f_list)}"
        pfinal = f"{round(np.mean(p_list), 4)} +- {round(np.std(p_list), 4)}"
        rfinal = f"{round(np.mean(r_list), 4)} +- {round(np.std(r_list), 4)}"
        ffinal = f"{round(np.mean(f_list), 4)} +- {round(np.std(f_list), 4)}"
        line.append(pfinal)
        line.append(rfinal)
        line.append(ffinal)
        ret.append(line)
    return ret
    

shot = 2
cols = ["model", "class type"]
for i in range(6):
    #for t in terms:
    for m in metrics:
        #cols.append(f"{t}_{m}")
        cols.append(f"{i}_{m}")
result_list = []
result_list.append(cols)
base_path = f"./results/eppc{shot}"
for model in models:
    model_name = model.replace("/", "__")
    print (model_name)
    for name in os.listdir(base_path):
        if model_name.lower() in name.lower():
            # select the model
            new_path = os.path.join(base_path, name)
            temps = []
            for res_json in os.listdir(new_path):
                if ".json" in res_json and ".jsonl" not in res_json:
                    with open(os.path.join(base_path, name, res_json), "r") as f:
                        data = json.load(f)
                    if data["n-shot"]["EppcExtraction"] == shot:
                        temp = data["results"]["EppcExtraction"]["evaluate_eppc,none"]
                        temps.append(temp)
            temp_results = get_list(model_name, temps)    # 3x(2 + 15 + 3)  
            for temp_result in temp_results:
                result_list.append(temp_result)
            
#print (result_list)
with open (f"shot{shot}_results.csv", "w", newline="") as f:
    writer = csv.writer(f)
    writer.writerows(result_list)
# Out:
# google__gemma-2-27b-it
# deepseek-ai__DeepSeek-R1-Distill-Qwen-32B
# Qwen__QwQ-32B-AWQ
# YanAdjeNole__sdoh-llama-3.3-70b

# %%
result_list
# Out:
# [['model',
#   'class type',
#   '0_P',
#   '0_R',
#   '0_f1',
#   '1_P',
#   '1_R',
#   '1_f1',
#   '2_P',
#   '2_R',
#   '2_f1',
#   '3_P',
#   '3_R',
#   '3_f1',
#   '4_P',
#   '4_R',
#   '4_f1',
#   '5_P',
#   '5_R',
#   '5_f1'],
#  ['google__gemma-2-27b-it',
#   'code',
#   0.5186,
#   0.5351,
#   0.5267,
#   0.5186,
#   0.5351,
#   0.5267,
#   0.5186,
#   0.5351,
#   0.5267,
#   0.5186,
#   0.5351,
#   0.5267,
#   0.5186,
#   0.5351,
#   0.5267,
#   '0.5186 +- 0.0',
#   '0.5351 +- 0.0',
#   '0.5267 +- 0.0'],
#  ['google__gemma-2-27b-it',
#   'sub-code',
#   0.3022,
#   0.3156,
#   0.3088,
#   0.3022,
#   0.3156,
#   0.3088,
#   0.3022,
#   0.3156,
#   0.3088,
#   0.3022,
#   0.3156,
#   0.3088,
#   0.3022,
#   0.3156,
#   0.3088,
#   '0.3022 +- 0.0',
#   '0.3156 +- 0.0',
#   '0.3088 +- 0.0'],
#  ['google__gemma-2-27b-it',
#   'span',
#   0.6276,
#   0.7256,
#   0.6731,
#   0.6276,
#   0.7256,
#   0.6731,
#   0.6276,
#   0.7256,
#   0.6731,
#   0.6276,
#   0.7256,
#   0.6731,
#   0.6276,
#   0.7256,
#   0.6731,
#   '0.6276 +- 0.0',
#   '0.7256 +- 0.0',
#   '0.6731 +- 0.0'],
#  ['deepseek-ai__DeepSeek-R1-Distill-Qwen-32B',
#   'code',
#   0.655,
#   0.6742,
#   0.6645,
#   0.655,
#   0.6742,
#   0.6645,
#   0.655,
#   0.6742,
#   0.6645,
#   0.655,
#   0.6742,
#   0.6645,
#   0.655,
#   0.6742,
#   0.6645,
#   '0.655 +- 0.0',
#   '0.6742 +- 0.0',
#   '0.6645 +- 0.0'],
#  ['deepseek-ai__DeepSeek-R1-Distill-Qwen-32B',
#   'sub-code',
#   0.4692,
#   0.4903,
#   0.4795,
#   0.4692,
#   0.4903,
#   0.4795,
#   0.4692,
#   0.4903,
#   0.4795,
#   0.4692,
#   0.4903,
#   0.4795,
#   0.4692,
#   0.4903,
#   0.4795,
#   '0.4692 +- 0.0',
#   '0.4903 +- 0.0',
#   '0.4795 +- 0.0'],
#  ['deepseek-ai__DeepSeek-R1-Distill-Qwen-32B',
#   'span',
#   0.7587,
#   0.7865,
#   0.7724,
#   0.7587,
#   0.7865,
#   0.7724,
#   0.7587,
#   0.7865,
#   0.7724,
#   0.7587,
#   0.7865,
#   0.7724,
#   0.7587,
#   0.7865,
#   0.7724,
#   '0.7587 +- 0.0',
#   '0.7865 +- 0.0',
#   '0.7724 +- 0.0'],
#  ['Qwen__QwQ-32B-AWQ',
#   'code',
#   0.7517,
#   0.5476,
#   0.6336,
#   0.7517,
#   0.5476,
#   0.6336,
#   0.7517,
#   0.5476,
#   0.6336,
#   0.7517,
#   0.5476,
#   0.6336,
#   0.7517,
#   0.5476,
#   0.6336,
#   '0.7517 +- 0.0',
#   '0.5476 +- 0.0',
#   '0.6336 +- 0.0'],
#  ['Qwen__QwQ-32B-AWQ',
#   'sub-code',
#   0.5664,
#   0.4014,
#   0.4698,
#   0.5664,
#   0.4014,
#   0.4698,
#   0.5664,
#   0.4014,
#   0.4698,
#   0.5664,
#   0.4014,
#   0.4698,
#   0.5664,
#   0.4014,
#   0.4698,
#   '0.5664 +- 0.0',
#   '0.4014 +- 0.0',
#   '0.4698 +- 0.0'],
#  ['Qwen__QwQ-32B-AWQ',
#   'span',
#   0.7766,
#   0.5759,
#   0.6614,
#   0.7766,
#   0.5759,
#   0.6614,
#   0.7766,
#   0.5759,
#   0.6614,
#   0.7766,
#   0.5759,
#   0.6614,
#   0.7766,
#   0.5759,
#   0.6614,
#   '0.7766 +- 0.0',
#   '0.5759 +- 0.0',
#   '0.6614 +- 0.0'],
#  ['YanAdjeNole__sdoh-llama-3.3-70b',
#   'code',
#   0.6642,
#   0.6303,
#   0.6468,
#   0.6642,
#   0.6303,
#   0.6468,
#   0.6642,
#   0.6303,
#   0.6468,
#   0.6642,
#   0.6303,
#   0.6468,
#   0.6642,
#   0.6303,
#   0.6468,
#   '0.6642 +- 0.0',
#   '0.6303 +- 0.0',
#   '0.6468 +- 0.0'],
#  ['YanAdjeNole__sdoh-llama-3.3-70b',
#   'sub-code',
#   0.4343,
#   0.416,
#   0.425,
#   0.4343,
#   0.416,
#   0.425,
#   0.4343,
#   0.416,
#   0.425,
#   0.4343,
#   0.416,
#   0.425,
#   0.4343,
#   0.416,
#   0.425,
#   '0.4343 +- 0.0',
#   '0.416 +- 0.0',
#   '0.425 +- 0.0'],
#  ['YanAdjeNole__sdoh-llama-3.3-70b',
#   'span',
#   0.6909,
#   0.7104,
#   0.7005,
#   0.6909,
#   0.7104,
#   0.7005,
#   0.6909,
#   0.7104,
#   0.7005,
#   0.6909,
#   0.7104,
#   0.7005,
#   0.6909,
#   0.7104,
#   0.7005,
#   '0.6909 +- 0.0',
#   '0.7104 +- 0.0',
#   '0.7005 +- 0.0']]

# %%
"deepseek-ai/DeepSeek-V3".replace("/", "__")
# Out:
# 'deepseek-ai__DeepSeek-V3'

# %%
import numpy as np
a = [1,2,3]
round(np.mean(a), 4)
# Out:
# np.float64(2.0)

# %%
round(np.std(a), 4)
# Out:
# np.float64(0.8165)
